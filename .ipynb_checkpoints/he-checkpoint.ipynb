# %%
import app
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, when, lit
import time
import pcmiller

# %%
import pcmiller

# %%
ret = pcmiller.get_coords_by_zipcode("53703")
# Out:
# Error 403:
